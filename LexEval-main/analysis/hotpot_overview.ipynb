# %%
from datasets import load_dataset

# %%
dataset = load_dataset("hotpotqa/hotpot_qa", "fullwiki", split="train")
print(dataset.shape)
print(dataset.column_names)
# Out:
# /vol/bitbucket/lst20/lex-eval/lib/python3.12/site-packages/datasets/load.py:1486: FutureWarning: The repository for hotpotqa/hotpot_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/hotpotqa/hotpot_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# (90447, 7)
# ['id', 'question', 'answer', 'type', 'level', 'supporting_facts', 'context']

# %%
question_types = set(dataset["type"])
question_types
# Out:
# {'bridge', 'comparison'}

# %%
import pandas as pd

# %%
df = dataset.to_pandas()
# df[["question", 'answer','type','supporting_facts', 'context']][:1]
i = 5
print(df["question"].iloc[i])
print(df["type"].iloc[i])
print(df["supporting_facts"].iloc[i])
print(df["context"].iloc[i])
# Out:
# Which tennis player won more Grand Slam titles, Henri Leconte or Jonathan Stark?
# comparison
# {'title': array(['Jonathan Stark (tennis)', 'Jonathan Stark (tennis)',
#        'Henri Leconte'], dtype=object), 'sent_id': array([0, 1, 1], dtype=int32)}
# {'title': array(['Li Na', 'Williams sisters', 'Henri Leconte', 'Steffi Graf',
#        '1986 Grand Prix German Open', 'Jonathan Stark (tennis)',
#        'Pam Teeguarden', 'Ken Rosewall',
#        '2009 Serena Williams tennis season', 'Larisa Neiland'],
#       dtype=object), 'sentences': array([array(['Li Na (; ; born 26 February 1982) is a retired Chinese professional tennis player, who achieved a career-high WTA-ranking of world No. 2 on 17 February 2014.',
#               ' Over the course of her career, Li won seven WTA singles titles and two Grand Slam singles titles at the 2011 French Open and 2014 Australian Open.',
# ...
